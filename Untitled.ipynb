# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from ebmdatalab import bq
import os
import requests
from io import StringIO

# %%
# Specify the GitHub repository information
repo_owner = 'ebmdatalab'
repo_name = 'openprescribing/openprescribing/frontend/management/commands/presentation_replacements'
base_url = f'https://api.github.com/repos/{repo_owner}/{repo_name}/contents/'

# Get the list of all files in the repository
response = requests.get(base_url)
if response.status_code == 200:
    repo_contents = response.json()

    # Filter for only .txt files
    txt_files = [file['name'] for file in repo_contents if file['name'].endswith('.txt')]

    # Loop through each .txt file and import as a DataFrame
    for txt_file in txt_files:
        file_url = base_url + txt_file
        # Fetch the content of the file
        response = requests.get(file_url)
        if response.status_code == 200:
            content = response.text
            # Assuming your .txt files are delimited (e.g., CSV), adjust the separator accordingly
            df = pd.read_csv(StringIO(content), delimiter='\t')  # Replace '\t' with the appropriate separator
            # Display or process the DataFrame as needed
            print(f"DataFrame for {txt_file}:\n{df}\n")
        else:
            print(f"Failed to fetch {txt_file}. Status code: {response.status_code}")
else:
    print(f"Failed to fetch repository contents. Status code: {response.status_code}")
# Out:
# Failed to fetch repository contents. Status code: 404

# %%
res = requests.get('https://api.github.com/repos/ebmdatalab/openprescribing/contents/openprescribing/frontend/management/commands/presentation_replacements') #uses GitHub API to get list of all files listed in measure definitions - defaults to main branch
data = res.text #creates text from API result
df = pd.read_json(data) #turns JSON from API result into dataframe

# %%
df.head()
# Out:
#        name                                               path  \
# 0  2010.txt  openprescribing/frontend/management/commands/p...
# 1  2011.txt  openprescribing/frontend/management/commands/p...
# 2  2012.txt  openprescribing/frontend/management/commands/p...
# 3  2013.txt  openprescribing/frontend/management/commands/p...
# 4  2014.txt  openprescribing/frontend/management/commands/p...
#
#                                         sha  size  \
# 0  41fea5049304d0606a27a426edc305738f84cdf1  2338
# 1  413dcdd0391f9faa1c7564b303cea5adf7ad8c78  1234
# 2  7534f93db2bcc6eaa2f32784f32fa87c33ad31aa  1976
# 3  524fd0836a2c2f7e37285b48b51db24dfd193060  2299
# 4  14349fc8e21ebd3808f73306d851acf2e7b88e52  1644
#
#                                                  url  \
# 0  https://api.github.com/repos/ebmdatalab/openpr...
# 1  https://api.github.com/repos/ebmdatalab/openpr...
# 2  https://api.github.com/repos/ebmdatalab/openpr...
# 3  https://api.github.com/repos/ebmdatalab/openpr...
# 4  https://api.github.com/repos/ebmdatalab/openpr...
#
#                                             html_url  \
# 0  https://github.com/ebmdatalab/openprescribing/...
# 1  https://github.com/ebmdatalab/openprescribing/...
# 2  https://github.com/ebmdatalab/openprescribing/...
# 3  https://github.com/ebmdatalab/openprescribing/...
# 4  https://github.com/ebmdatalab/openprescribing/...
#
#                                              git_url  \
# 0  https://api.github.com/repos/ebmdatalab/openpr...
# 1  https://api.github.com/repos/ebmdatalab/openpr...
# 2  https://api.github.com/repos/ebmdatalab/openpr...
# 3  https://api.github.com/repos/ebmdatalab/openpr...
# 4  https://api.github.com/repos/ebmdatalab/openpr...
#
#                                         download_url  type  \
# 0  https://raw.githubusercontent.com/ebmdatalab/o...  file
# 1  https://raw.githubusercontent.com/ebmdatalab/o...  file
# 2  https://raw.githubusercontent.com/ebmdatalab/o...  file
# 3  https://raw.githubusercontent.com/ebmdatalab/o...  file
# 4  https://raw.githubusercontent.com/ebmdatalab/o...  file
#
#                                               _links
# 0  {'self': 'https://api.github.com/repos/ebmdata...
# 1  {'self': 'https://api.github.com/repos/ebmdata...
# 2  {'self': 'https://api.github.com/repos/ebmdata...
# 3  {'self': 'https://api.github.com/repos/ebmdata...
# 4  {'self': 'https://api.github.com/repos/ebmdata...

# %%
codes_df = pd.DataFrame() #creates blank dataframe
for row in df[df['name'].str.contains('.txt')].itertuples(index=True): #iterates through rows, and continues if file is .json
        url = (getattr(row, "download_url")) #gets URL from API request  
        year_df=pd.read_csv(url,sep='\t',header=None, names=['old_bnf_code', 'new_bnf_code'])
        year_df['change_date'] = pd.to_datetime(row.name[:4], format='%Y').strftime('%Y-%m-%d') # adds the year of change from the file name
        codes_df = pd.concat([codes_df,year_df], axis=0, ignore_index=True) # concatentates into single dataframe

# %%
year_df.head()
# Out:
#       old_bnf_code     new_bnf_code change_date
# 0  0101010F0BDAAAU  0101010F0BDABBE  2023-01-01
# 1  0407041ACAAAAAA  0407042T0AAAAAA  2023-01-01
# 2  0407041ACAAABAB  0407042T0AAABAB  2023-01-01
# 3  0407041ACBBAAAA  0407042T0BBAAAA  2023-01-01
# 4  0407041ACBBABAB  0407042T0BBABAB  2023-01-01

# %%
print(codes_df)
# Out:
#          old_bnf_code     new_bnf_code change_date
# 0     0905013A0BBAAA0  0905013A0BBAAAF  2010-01-01
# 1     140300000BKBHA0  140300000BKBHAE  2010-01-01
# 2     140300000BKBGA0  140300000BKBGAD  2010-01-01
# 3     0408010ACAAAAAA   40801020AAAHAH  2010-01-01
# 4     0408010ACAAABAB   40801020AAAIAI  2010-01-01
# ...               ...              ...         ...
# 2894  190700000BBCZA0  0913161A0BFABAB  2023-01-01
# 2895  190700000BBDABP  0913161A0BDAAAF  2023-01-01
# 2896  191300000BMCHA0  0913171B0BBABAB  2023-01-01
# 2897  191300000BMCIA0  0913171B0BBAAAA  2023-01-01
# 2898  191300000BMCUA0  0913421A0BBAAAA  2023-01-01
#
# [2899 rows x 3 columns]

# %%
#bnf_code_list = (codes_df['old_bnf_code'] + codes_df['new_bnf_code']).tolist()

old_bnf_code_list = codes_df['old_bnf_code'].astype(str).tolist()
new_bnf_code_list = codes_df['new_bnf_code'].astype(str).tolist()
bnf_code_list = old_bnf_code_list + new_bnf_code_list

# %%
in_clause = "(BNF_CODE LIKE '" +"%' OR BNF_CODE LIKE '".join(bnf_code_list) + "')"
where = "WHERE " +in_clause
print(where)
# Out:
# WHERE (BNF_CODE LIKE '0905013A0BBAAA0%' OR BNF_CODE LIKE '140300000BKBHA0%' OR BNF_CODE LIKE '140300000BKBGA0%' OR BNF_CODE LIKE '0408010ACAAAAAA%' OR BNF_CODE LIKE '0408010ACAAABAB%' OR BNF_CODE LIKE '0408010ACBBAAAA%' OR BNF_CODE LIKE '0408010ACBBABAB%' OR BNF_CODE LIKE '030902000BEAYA0%' OR BNF_CODE LIKE '030902000BEDFA0%' OR BNF_CODE LIKE '1305000AAAAAAAA%' OR BNF_CODE LIKE '1305000AAAAABAB%' OR BNF_CODE LIKE '1305000AAAAACAC%' OR BNF_CODE LIKE '1305000AABB%' OR BNF_CODE LIKE '1305000AABBAAAA%' OR BNF_CODE LIKE '1305000AABBABAB%' OR BNF_CODE LIKE '1305000AABBACAC%' OR BNF_CODE LIKE '0604011AC%' OR BNF_CODE LIKE '0604011ACAA%' OR BNF_CODE LIKE '0604011ACAAAAAA%' OR BNF_CODE LIKE '0604011ACBB%' OR BNF_CODE LIKE '0604011ACBBAAAA%' OR BNF_CODE LIKE '0906027G0BIAAAB%' OR BNF_CODE LIKE '0908010AK%' OR BNF_CODE LIKE '0908010AKAA%' OR BNF_CODE LIKE '0908010AKAAAAAA%' OR BNF_CODE LIKE '0908010AKBB%' OR BNF_CODE LIKE '0908010AKBBAAAA%' OR BNF_CODE LIKE '1001050A0BFAAAD%' OR BNF_CODE LIKE '0501100J0BB%' OR BNF_CODE LIKE '0501100J0BBAAAB%' OR BNF_CODE LIKE '0404000L0BFAFBA%' OR BNF_CODE LIKE '0404000L0BFAEAZ%' OR BNF_CODE LIKE '0404000L0BFABAJ%' OR BNF_CODE LIKE '0106040M0BBAEAF%' OR BNF_CODE LIKE '0106040M0BCABAD%' OR BNF_CODE LIKE '0106040M0BBADAD%' OR BNF_CODE LIKE '0602010W0BDAAAN%' OR BNF_CODE LIKE '0602010W0BDABAM%' OR BNF_CODE LIKE '0602010W0BDACAP%' OR BNF_CODE LIKE '0602010W0BDADAQ%' OR BNF_CODE LIKE '0602010W0BDAEAR%' OR BNF_CODE LIKE '0602010W0BDAFAS%' OR BNF_CODE LIKE '0602010W0BDAGAT%' OR BNF_CODE LIKE '0602010W0BDAHAU%' OR BNF_CODE LIKE '120301000AAAQAQ%' OR BNF_CODE LIKE '120301000BCBAAQ%' OR BNF_CODE LIKE '20031800010%' OR BNF_CODE LIKE '20031800011%' OR BNF_CODE LIKE '20031800012%' OR BNF_CODE LIKE '20031800015%' OR BNF_CODE LIKE '20031800016%' OR BNF_CODE LIKE '20031800017%' OR BNF_CODE LIKE '20031800018%' OR BNF_CODE LIKE '20032000001%' OR BNF_CODE LIKE '0105000W0%' OR BNF_CODE LIKE '0105000W0AA%' OR BNF_CODE LIKE '0105000W0AAAAAA%' OR BNF_CODE LIKE '0105000W0BB%' OR BNF_CODE LIKE '0105000W0BBAAAA%' OR BNF_CODE LIKE '0501020B0%' OR BNF_CODE LIKE '0501020D0%' OR BNF_CODE LIKE '0501020E0%' OR BNF_CODE LIKE '0501020F0%' OR BNF_CODE LIKE '0501020H0%' OR BNF_CODE LIKE '0501020I0%' OR BNF_CODE LIKE '0501020K0%' OR BNF_CODE LIKE '0501020L0%' OR BNF_CODE LIKE '0501020M0%' OR BNF_CODE LIKE '0501020P0%' OR BNF_CODE LIKE '0501020Q0%' OR BNF_CODE LIKE '0501020R0%' OR BNF_CODE LIKE '0501020W0%' OR BNF_CODE LIKE '050102010%' OR BNF_CODE LIKE '0501020AB%' OR BNF_CODE LIKE '0501020AC%' OR BNF_CODE LIKE '0501020X0%' OR BNF_CODE LIKE '0501020A0%' OR BNF_CODE LIKE '0501020C0%' OR BNF_CODE LIKE '010500%' OR BNF_CODE LIKE '010500%' OR BNF_CODE LIKE '010500%' OR BNF_CODE LIKE '010500%' OR BNF_CODE LIKE '1405000C0%' OR BNF_CODE LIKE '1405000G0%' OR BNF_CODE LIKE '1405000N0%' OR BNF_CODE LIKE '1405000V0%' OR BNF_CODE LIKE '1405000Y0%' OR BNF_CODE LIKE '1405000L0%' OR BNF_CODE LIKE '1405000A0%' OR BNF_CODE LIKE '1405000Z0%' OR BNF_CODE LIKE '140500%' OR BNF_CODE LIKE '140500%' OR BNF_CODE LIKE '140500%' OR BNF_CODE LIKE '190205200BBBDA0%' OR BNF_CODE LIKE '0904010A0BPAABF%' OR BNF_CODE LIKE '091200000BFISA0%' OR BNF_CODE LIKE '0106040M0BBAEAE%' OR BNF_CODE LIKE '091200000BFEPA0%' OR BNF_CODE LIKE '0904010AKBBABAA%' OR BNF_CODE LIKE '0906011H0BDAFA0%' OR BNF_CODE LIKE '0211000J0BBAAAB%' OR BNF_CODE LIKE '0101021B0BEAKAL%' OR BNF_CODE LIKE '0606020W0BBADAE%' OR BNF_CODE LIKE '1306020K0%' OR BNF_CODE LIKE '1306020K0AA%' OR BNF_CODE LIKE '1306020K0AAAAAA%' OR BNF_CODE LIKE '1306020K0BB%' OR BNF_CODE LIKE '1306020K0BBAAAA%' OR BNF_CODE LIKE '0604020W0%' OR BNF_CODE LIKE '0604020W0AA%' OR BNF_CODE LIKE '0604020W0AAAAAA%' OR BNF_CODE LIKE '0604020W0BB%' OR BNF_CODE LIKE '0604020W0BBAAAA%' OR BNF_CODE LIKE '1311020L0CIAAAF%' OR BNF_CODE LIKE '0801050AYAAAAAA%' OR BNF_CODE LIKE '0801050AYBB%' OR BNF_CODE LIKE '0801050AYBBAAAA%' OR BNF_CODE LIKE '0407030AEAAAAAA%' OR BNF_CODE LIKE '0407030AEBB%' OR BNF_CODE LIKE '0407030AEBBAAAA%' OR BNF_CODE LIKE '0 ...

# %%
#pull data from BigQuery for antibiotic stewardship: co-amoxiclav, cephalosporins & quinolones (KTT9) measure
in_clause = "(BNF_CODE LIKE '" +"%' OR BNF_CODE LIKE '".join(bnf_code_list) + "')"
#where = "WHERE " +in_clause
#print(where)
sql = f"""
SELECT
  month,
  bnf_code,
  bnf_name,
  items
FROM
  richard.all_prescribing_items
WHERE {in_clause}
  """
exportfile = os.path.join("..","data","items_df.csv")
items_df = bq.cached_read(sql, csv_path=exportfile, use_cache=True)
# Out:
# Downloading: 100%|██████████| 257678/257678 [00:13<00:00, 18730.54rows/s]

# %%
items_df.head()
# Out:
#        month         bnf_code                                   bnf_name  \
# 0 2014-03-01  090401000BBQZA0      TYR express20 oral powder 34g sachets
# 1 2014-03-01  0904010U0BDARAA        Ener-G gluten free flax loaf sliced
# 2 2014-03-01  090401000BBUBA0          Vital 1.5kcal liquid (3 flavours)
# 3 2014-03-01  090402000BBTJA0          Fresubin 5kcal shot drink neutral
# 4 2014-03-01  091200000BEWDDG  Valupak Glucosamine sulfate 500mg tablets
#
#    items
# 0      1
# 1      8
# 2    610
# 3    836
# 4    367

# %%
filtered_df = codes_df[codes_df['old_bnf_code'].apply(lambda x: len(str(x)) != 15)]

# %%
print(filtered_df)
# Out:
#     old_bnf_code new_bnf_code change_date  code_length
# 12   1305000AABB  1305020C0BS  2010-01-01           11
# 16     0604011AC    0703010R0  2010-01-01            9
# 17   0604011ACAA  0703010R0AA  2010-01-01           11
# 19   0604011ACBB  0703010R0BB  2010-01-01           11
# 22     0908010AK         None  2010-01-01            9
# ..           ...          ...         ...          ...
# 406  23701157000  23706607000  2017-01-01           11
# 407  23806258001  23802098003  2017-01-01           11
# 408  23806258002  23802098004  2017-01-01           11
# 409  23806258003  23802098005  2017-01-01           11
# 410  23806558000  23803938000  2017-01-01           11
#
# [187 rows x 4 columns]

# %%
#pull data from BigQuery for antibiotic stewardship: co-amoxiclav, cephalosporins & quinolones (KTT9) measure
sql = """
SELECT *
FROM hscic.bnf
  """
exportfile = os.path.join("..","data","bnf_df.csv")
bnf_df = bq.cached_read(sql, csv_path=exportfile, use_cache=False)
# Out:
# Downloading: 100%|██████████| 53993/53993 [00:05<00:00, 9052.37rows/s]

# %%
pd.options.mode.chained_assignment = None # suppress warning
filtered_df['code_length'] = filtered_df['old_bnf_code'].astype(str).apply(len)

# %%
df1 = pd.DataFrame({'A': ['a', 'b', 'cc']})

df2 = pd.DataFrame({'B': ['ar', 'd', 'ar'],
                    'C': ['x1', 'x1', 'x2']})

# %%
df1.head()
# Out:
#     A
# 0   a
# 1   b
# 2  cc

# %%
df2.head()
# Out:
#     B   C
# 0  ar  x1
# 1   d  x1
# 2  ar  x2

# %%
key = df2['B'].str.extract('^(' + '|'.join(df1['A']) + ')')

# %%
key.head()
# Out:
#      0
# 0    a
# 1  NaN
# 2    a

# %%
df3 = df1.merge(df2.assign(key=key), left_on='A', right_on='key').drop('key', 1)

# %%
df3.head()
# Out:
#    A   B   C
# 0  a  ar  x1
# 1  a  ar  x2

# %%
items_df.head()
# Out:
#        month         bnf_code                                   bnf_name  \
# 0 2014-03-01  090401000BBQZA0      TYR express20 oral powder 34g sachets
# 1 2014-03-01  0904010U0BDARAA        Ener-G gluten free flax loaf sliced
# 2 2014-03-01  090401000BBUBA0          Vital 1.5kcal liquid (3 flavours)
# 3 2014-03-01  090402000BBTJA0          Fresubin 5kcal shot drink neutral
# 4 2014-03-01  091200000BEWDDG  Valupak Glucosamine sulfate 500mg tablets
#
#    items
# 0      1
# 1      8
# 2    610
# 3    836
# 4    367

# %%
codes_df.head()
# Out:
#       old_bnf_code     new_bnf_code change_date
# 0  0905013A0BBAAA0  0905013A0BBAAAF  2010-01-01
# 1  140300000BKBHA0  140300000BKBHAE  2010-01-01
# 2  140300000BKBGA0  140300000BKBGAD  2010-01-01
# 3  0408010ACAAAAAA   40801020AAAHAH  2010-01-01
# 4  0408010ACAAABAB   40801020AAAIAI  2010-01-01

# %%
key = items_df['bnf_code'].str.extract('^(' + '|'.join(codes_df['old_bnf_code']) + ')')

# %%
key.head()
# Out:
#                  0
# 0  090401000BBQZA0
# 1  0904010U0BDARAA
# 2  090401000BBUBA0
# 3  090402000BBTJA0
# 4              NaN

# %%
df3 = codes_df.merge(items_df.assign(key=key), left_on='old_bnf_code', right_on='key').drop('key', 1)

# %%
df3.head()
# Out:
#       old_bnf_code     new_bnf_code change_date      month         bnf_code  \
# 0  190205200BBBDA0  190400000BBBRUI  2011-01-01 2010-09-01  190205200BBBDA0
# 1  190205200BBBDA0  190400000BBBRUI  2011-01-01 2010-08-01  190205200BBBDA0
# 2  190205200BBBDA0  190400000BBBRUI  2011-01-01 2010-10-01  190205200BBBDA0
# 3  0106040M0BBAEAE  0106040M0BBAEAA  2011-01-01 2010-10-01  0106040M0BBAEAE
# 4  0106040M0BBAEAE  0106040M0BBAEAA  2011-01-01 2010-08-01  0106040M0BBAEAE
#
#                                    bnf_name  items
# 0  After Bite_Insect Bite TT Pen                50
# 1  After Bite_Insect Bite TT Pen                41
# 2  After Bite_Insect Bite TT Pen                53
# 3  Movicol_Pdr Sach 13.9g (Choc)              2615
# 4  Movicol_Pdr Sach 13.9g (Choc)              2739

# %%
filtered_df = df3[df3['old_bnf_code'].apply(lambda x: len(str(x)) != 15)]

# %%
filtered_df.head()
# Out:
#    old_bnf_code new_bnf_code change_date      month         bnf_code  \
# 11    1306020K0    0501030Z0  2011-01-01 2010-09-01  1306020K0BBAAAA
# 12    1306020K0    0501030Z0  2011-01-01 2010-08-01  1306020K0AAAAAA
# 13    1306020K0    0501030Z0  2011-01-01 2010-10-01  1306020K0BBAAAA
# 14    1306020K0    0501030Z0  2011-01-01 2010-09-01  1306020K0AAAAAA
# 15    1306020K0    0501030Z0  2011-01-01 2010-10-01  1306020K0AAAAAA
#
#                                     bnf_name  items
# 11  Efracea_Cap 40mg M/R                         80
# 12  Doxycycline_Cap 40mg M/R                    228
# 13  Efracea_Cap 40mg M/R                         58
# 14  Doxycycline_Cap 40mg M/R                    236
# 15  Doxycycline_Cap 40mg M/R                    252

# %%
df3['month'] = pd.to_datetime(df3['month'])

# %%
df3['change_date'] = pd.to_datetime(df3['change_date'])

# %%
filtered_df = df3[df3['month'] > df3['change_date']]

# %%
filtered_df.head(500)
# Out:
#           old_bnf_code             new_bnf_code change_date      month  \
# 53312  0408010AHBBAGAG  Withdrawn (no new code)  2013-01-01 2013-04-01
# 53314  0408010AHBBAGAG  Withdrawn (no new code)  2013-01-01 2013-09-01
# 53318  0408010AHBBAGAG  Withdrawn (no new code)  2013-01-01 2013-05-01
# 53319  0408010AHBBAGAG  Withdrawn (no new code)  2013-01-01 2013-08-01
# 53321  0408010AHBBAGAG  Withdrawn (no new code)  2013-01-01 2013-06-01
# ...                ...                      ...         ...        ...
# 61232  1306010ACBBAAAA          1306030B0BBAAAA  2018-01-01 2023-05-01
# 61233  1306010ACBBAAAA          1306030B0BBAAAA  2018-01-01 2022-11-01
# 61234  1306010ACBBAAAA          1306030B0BBAAAA  2018-01-01 2023-09-01
# 61235  1306010ACBBAAAA          1306030B0BBAAAA  2018-01-01 2023-03-01
# 61236  1306010ACBBAAAA          1306030B0BBAAAA  2018-01-01 2023-04-01
#
#               bnf_code                                  bnf_name  items
# 53312  0408010AHBBAGAG  Vimpat_Syr 10mg/ml                            2
# 53314  0408010AHBBAGAG  Vimpat_Syr 10mg/ml                            1
# 53318  0408010AHBBAGAG  Vimpat_Syr 10mg/ml                            2
# 53319  0408010AHBBAGAG  Vimpat_Syr 10mg/ml                            2
# 53321  0408010AHBBAGAG  Vimpat_Syr 10mg/ml                            6
# ...                ...                                       ...    ...
# 61232  1306010ACBBAAAA               Aklief 50micrograms/g cream     31
# 61233  1306010ACBBAAAA               Aklief 50micrograms/g cream      4
# 61234  1306010ACBBAAAA               Aklief 50micrograms/g cream     76
# 61235  1306010ACBBAAAA               Aklief 50micrograms/g cream     17
# 61236  1306010ACBBAAAA               Aklief 50micrograms/g cream     21
#
# [354 rows x 7 columns]

# %%
result_df = filtered_df.groupby(['old_bnf_code', 'new_bnf_code', 'bnf_name', 'change_date']).agg({'items': 'sum', 'month': 'max'}).reset_index().sort_values(by='items', ascending=False).rename(columns={'month': 'latest_month'})

# %%
result_df.head(200)
# Out:
#        old_bnf_code             new_bnf_code  \
# 1   0301040V0BBAAAA          0301020U0BBAAAA
# 0   0301040V0AAAAAA          0301020U0AAAAAA
# 3   0302000W0BBAAAA          0304020Z0BBAAAA
# 7   0604011L0CCAABM          0703010S0BBAAAA
# 6   0604011L0AABMBM          0703010S0AAAAAA
# 8   1306010ACAAAAAA          1306030B0AAAAAA
# 9   1306010ACBBAAAA          1306030B0BBAAAA
# 10  1404000X0AAAHAH          1404000AQAAAAAA
# 11  1404000X0BKAAAH          1404000AQBBAAAA
# 2   0302000W0AAAAAA          0304020Z0AAAAAA
# 5   0408010AHBBAGAG  Withdrawn (no new code)
# 4   0407010X0CDACBF              NEEDS ENDED
#
#                                              bnf_name change_date    items  \
# 1   Duaklir 340micrograms/dose / 12micrograms/dose...  2017-01-01  1086096
# 0   Aclidinium brom 396mcg/dose / Formoterol 11.8m...  2017-01-01    94468
# 3   Enerzair Breezhaler 114microg / 46microg / 136...  2018-01-01    20518
# 7                           Bijuve 1mg/100mg capsules  2014-01-01     8420
# 6         Estradiol 1mg / Progesterone 100mg capsules  2014-01-01     3037
# 8                    Trifarotene 50micrograms/g cream  2018-01-01      632
# 9                         Aklief 50micrograms/g cream  2018-01-01      573
# 10  Meningococcal polysacch A, C, W135 & Y conj va...  2017-01-01      105
# 11  MenQuadfi vaccine solution for injection 0.5ml...  2017-01-01       91
# 2   Generic Enerzair Breezhaler 114/46/136microg i...  2018-01-01       82
# 5            Vimpat_Syr 10mg/ml                        2013-01-01       23
# 4                          Dental Pain Relief tablets  2013-01-01        1
#
#    latest_month
# 1    2023-11-01
# 0    2023-11-01
# 3    2023-11-01
# 7    2023-11-01
# 6    2023-11-01
# 8    2023-11-01
# 9    2023-11-01
# 10   2023-10-01
# 11   2023-11-01
# 2    2023-11-01
# 5    2013-09-01
# 4    2014-01-01

# %%
merged_df = pd.merge(result_df, items_df, left_on='new_bnf_code', right_on='bnf_code', how='inner')

# %%
merged_df.head()
# Out:
#       old_bnf_code     new_bnf_code                 bnf_name_x change_date  \
# 0  0604011L0CCAABM  0703010S0BBAAAA  Bijuve 1mg/100mg capsules  2014-01-01
# 1  0604011L0CCAABM  0703010S0BBAAAA  Bijuve 1mg/100mg capsules  2014-01-01
# 2  0604011L0CCAABM  0703010S0BBAAAA  Bijuve 1mg/100mg capsules  2014-01-01
# 3  0604011L0CCAABM  0703010S0BBAAAA  Bijuve 1mg/100mg capsules  2014-01-01
# 4  0604011L0CCAABM  0703010S0BBAAAA  Bijuve 1mg/100mg capsules  2014-01-01
#
#    items_x latest_month      month         bnf_code  \
# 0     8420   2023-11-01 2019-02-01  0703010S0BBAAAA
# 1     8420   2023-11-01 2021-12-01  0703010S0BBAAAA
# 2     8420   2023-11-01 2023-05-01  0703010S0BBAAAA
# 3     8420   2023-11-01 2017-10-01  0703010S0BBAAAA
# 4     8420   2023-11-01 2014-05-01  0703010S0BBAAAA
#
#                   bnf_name_y  items_y
# 0  Zoely 2.5mg/1.5mg tablets      190
# 1  Zoely 2.5mg/1.5mg tablets      293
# 2  Zoely 2.5mg/1.5mg tablets      326
# 3  Zoely 2.5mg/1.5mg tablets      222
# 4  Zoely 2.5mg/1.5mg tablets      153

# %%
wrong_code_df =  merged_df.groupby(['old_bnf_code', 'new_bnf_code', 'bnf_name_x', 'bnf_name_y','change_date']).agg({'items_x':'sum', 'items_y': 'sum', 'month': 'max'})

# %%
wrong_code_df.head(200)
# Out:
#                                                                                                                                                    items_x  \
# old_bnf_code    new_bnf_code    bnf_name_x                                         bnf_name_y                                         change_date
# 0604011L0AABMBM 0703010S0AAAAAA Estradiol 1mg / Progesterone 100mg capsules        Estradiol 1.5mg / Nomegestrol 2.5mg tablets        2014-01-01    361403
#                                                                                    Estradiol/Nomegestrol_Tab 1.5mg/2.5mg              2014-01-01      6074
# 0604011L0CCAABM 0703010S0BBAAAA Bijuve 1mg/100mg capsules                          Zoely 2.5mg/1.5mg tablets                          2014-01-01   1001980
#                                                                                    Zoely_Tab 2.5mg/1.5mg                              2014-01-01     16840
# 1306010ACAAAAAA 1306030B0AAAAAA Trifarotene 50micrograms/g cream                   Ivermectin 10mg/g cream                            2018-01-01     64464
# 1306010ACBBAAAA 1306030B0BBAAAA Aklief 50micrograms/g cream                        Soolantra 10mg/g cream                             2018-01-01     58446
# 1404000X0AAAHAH 1404000AQAAAAAA Meningococcal polysacch A, C, W135 & Y conj vac... Generic Bexsero vaccine inj 0.5ml pre-filled sy... 2017-01-01      5565
# 1404000X0BKAAAH 1404000AQBBAAAA MenQuadfi vaccine solution for injection 0.5ml ... Bexsero vacc inj 0.5ml pre-filled syringes         2017-01-01     10829
#
#                                                                                                                                                    items_y  \
# old_bnf_code    new_bnf_code    bnf_name_x                                         bnf_name_y                                         change_date
# 0604011L0AABMBM 0703010S0AAAAAA Estradiol 1mg / Progesterone 100mg capsules        Estradiol 1.5mg / Nomegestrol 2.5mg tablets        2014-01-01      4666
#                                                                                    Estradiol/Nomegestrol_Tab 1.5mg/2.5mg              2014-01-01        49
# 0604011L0CCAABM 0703010S0BBAAAA Bijuve 1mg/100mg capsules                          Zoely 2.5mg/1.5mg tablets                          2014-01-01     23342
#                                                                                    Zoely_Tab 2.5mg/1.5mg                              2014-01-01       234
# 1306010ACAAAAAA 1306030B0AAAAAA Trifarotene 50micrograms/g cream                   Ivermectin 10mg/g cream                            2018-01-01    261887
# 1306010ACBBAAAA 1306030B0BBAAAA Aklief 50micrograms/g cream                        Soolantra 10mg/g cream                             2018-01-01    202454
# 1404000X0AAAHAH 1404000AQAAAAAA Meningococcal polysacch A, C, W135 & Y conj vac... Generic Bexsero vaccine inj 0.5ml pre-filled sy... 2017-01-01       286
# 1404000X0BKAAAH 1404000AQBBAAAA MenQuadfi vaccine solution for injection 0.5ml ... Bexsero vacc inj 0.5ml pre-filled syringes         2017-01-01     38819
#
#                                                                                                                                                        month
# old_bnf_code    new_bnf_code    bnf_name_x                                         bnf_name_y                                         change_date
# 0604011L0AABMBM 0703010S0AAAAAA Estradiol 1mg / Progesterone 100mg capsules        Estradiol 1.5mg / Nomegestrol 2.5mg tablets        2014-01-01  2023-11-01
#                                                                                    Estradiol/Nomegestrol_Tab 1.5mg/2.5mg              2014-01-01  2013-12-01
# 0604011L0CCAABM 0703010S0BBAAAA Bijuve 1mg/100mg capsules                          Zoely 2.5mg/1.5mg tablets                          2014-01-01  2023-11-01
#                                                                                    Zoely_Tab 2.5mg/1.5mg                              2014-01-01  2013-12-01
# 1306010ACAAAAAA 1306030B0AAAAAA Trifarotene 50micrograms/g cream                   Ivermectin 10mg/g cream                            2018-01-01  2023-11-01
# 1306010ACBBAAAA 1306030B0BBAAAA Aklief 50micrograms/g cream                        Soolantra 10mg/g cream                             2018-01-01  2023-11-01
# 1404000X0AAAHAH 1404000AQAAAAAA Meningococcal polysacch A, C, W135 & Y conj vac... Generic Bexsero vaccine inj 0.5ml pre-filled sy... 2017-01-01  2022-09-01
# 1404000X0BKAAAH 1404000AQBBAAAA MenQuadfi vaccine solution for injection 0.5ml ... Bexsero vacc inj 0.5ml pre-filled syringes         2017-01-01  2023-11-01
